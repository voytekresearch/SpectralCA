# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import sys
sys.path.append('/Users/Lauren/Voytek/spectralCV')
sys.path.append('/Users/rdgao/Documents/code/research/spectralCV')
sys.path.append('/Users/rdgao/Documents/code/research/neurodsp/')


# imports
import os
import numpy as np
import scipy as sp
import scipy.io as io
import matplotlib.pyplot as plt

import neurodsp as ndsp
from scv_funcs import lfpca

# %%
data_path = '/Users/rdgao/Documents/data/multielectrode_grasp/datasets_matlab/'
data_files = ['i140703-001_lfp-spikes.mat', 'l101210-001_lfp-spikes.mat']
#saveout_path = '../results/kjm_digits/'

# %%
data = io.loadmat(data_path+data_files[0], squeeze_me=True)

# %%
data['block']
# Out:
# array((1, 'motor behavior', '../datasets/i140703-001', 10, array([-1, 81, 83, 85, 88, 90, 92, 93, 96, -1, 79, 80, 84, 86, 87, 89, 91,
#        94, 63, 95, 77, 78, 82, 49, 53, 55, 57, 59, 61, 32, 75, 76, 45, 47,
#        51, 56, 58, 60, 64, 30, 73, 74, 41, 43, 44, 46, 52, 62, 31, 28, 71,
#        72, 39, 40, 42, 50, 54, 21, 29, 26, 69, 70, 37, 38, 48, 15, 19, 25,
#        27, 24, 67, 68, 35, 36,  5, 17, 13, 23, 20, 22, 65, 66, 33, 34,  7,
#         9, 11, 12, 16, 18, -1,  2,  1,  3,  4,  6,  8, 10, 14, -1]), 'reach-to-grasp', 'electrophysiology', '2008-05-17', 'CerePort', array([2, 6]), 'male', array((0, array([array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 93, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 1, label: chan1, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan1', array([ 58.25,  28.75,  12.5 , ..., -28.  , -26.5 , -23.25], dtype=float32), '(1.0/1000.0*s)', 'Hz', 1),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 92, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 2, label: chan2, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan2', array([12.75, -4.75, -1.25, ..., 10.5 ,  2.25, -8.  ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 2),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 94, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 3, label: chan3, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan3', array([ 48.75,  37.5 ,  32.25, ..., -49.25, -39.  , -24.  ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 3),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 95, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 4, label: chan4, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan4', array([ 97.75,  74.5 ,  58.5 , ..., -20.25, -30.5 ,  -9.25], dtype=float32), '(1.0/1000.0*s)', 'Hz', 4),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 75, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 5, label: chan5, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan5', array([18.75, 15.75, 20.75, ...,  1.5 , 14.75, 18.  ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 5),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 96, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 6, label: chan6, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan6', array([92.25, 70.  , 62.25, ..., -1.25,  1.25, -7.5 ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 6),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 85, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 7, label: chan7, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan7', array([112.5 , 110.5 ,  98.25, ..., -37.5 , -16.75, -20.  ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 7),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 97, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 8, label: chan8, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan8', array([59.25, 51.  , 45.75, ...,  5.75,  3.  ,  3.75], dtype=float32), '(1.0/1000.0*s)', 'Hz', 8),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 86, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 9, label: chan9, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan9', array([61.  , 56.75, 51.75, ..., 18.5 , 31.5 , 53.5 ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 9),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 98, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 10, label: chan10, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan10', array([67.25, 63.75, 65.25, ..., -4.75,  5.75, 18.5 ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 10),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 87, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 11, label: chan11, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan11', array([28.25, 20.5 , 12.5 , ..., 57.25, 60.75, 55.75], dtype=float32), '(1.0/1000.0*s)', 'Hz', 11),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 88, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 12, label: chan12, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan12', array([61.75, 56.5 , 47.75, ..., -1.75,  3.75,  1.5 ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 12),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 77, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 13, label: chan13, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan13', array([16.  , 15.25, 20.5 , ...,  3.  , -0.75,  1.75], dtype=float32), '(1.0/1000.0*s)', 'Hz', 13),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 99, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 14, label: chan14, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan14', array([ 81.75,  71.5 ,  64.  , ..., -22.  , -26.25, -26.  ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 14),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((1, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 66, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 15, label: chan15, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan15', array([-18.75, -22.25, -22.75, ..., -95.  , -88.25, -75.5 ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 15),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 89, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 16, label: chan16, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan16', array([86.5 , 82.5 , 82.  , ..., -5.  ,  3.75,  3.75], dtype=float32), '(1.0/1000.0*s)', 'Hz', 16),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 76, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 17, label: chan17, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan17', array([-9.25, -5.25,  1.75, ..., 53.  , 54.  , 46.75], dtype=float32), '(1.0/1000.0*s)', 'Hz', 17),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 90, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 18, label: chan18, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan18', array([ 63.  ,  54.5 ,  48.  , ..., -91.25, -87.5 , -83.  ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 18),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 67, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 19, label: chan19, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan19', array([16.25,  7.25,  1.  , ...,  8.  , 14.25, 16.75], dtype=float32), '(1.0/1000.0*s)', 'Hz', 19),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 79, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 20, label: chan20, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan20', array([104.  ,  86.  ,  71.5 , ...,  -0.25, -17.  , -24.25], dtype=float32), '(1.0/1000.0*s)', 'Hz', 20),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 58, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 21, label: chan21, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan21', array([-12. , -32. , -37. , ...,  12.5,  29. ,  20.5], dtype=float32), '(1.0/1000.0*s)', 'Hz', 21),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 80, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 22, label: chan22, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan22', array([53.  , 46.5 , 42.75, ...,  1.5 , 19.5 , 28.75], dtype=float32), '(1.0/1000.0*s)', 'Hz', 22),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((1, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 1, 'uV', 1, 'Hz', 78, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 23, label: chan23, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan23', array([-135.5 , -159.75, -168.  , ...,   37.75,   51.  ,   51.  ],
#       dtype=float32), '(1.0/1000.0*s)', 'Hz', 23),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 70, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 24, label: chan24, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan24', array([ 64.  ,  53.75,  41.25, ..., -40.25, -43.75, -76.75], dtype=float32), '(1.0/1000.0*s)', 'Hz', 24),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 68, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 25, label: chan25, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan25', array([18.25, 13.5 , 12.5 , ..., 26.75, 24.25,  5.75], dtype=float32), '(1.0/1000.0*s)', 'Hz', 25),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 60, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 26, label: chan26, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan26', array([ 44.5 ,  67.  ,  59.5 , ..., -37.  , -27.25, -27.25], dtype=float32), '(1.0/1000.0*s)', 'Hz', 26),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 69, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 27, label: chan27, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan27', array([56.5 , 33.5 , 20.  , ..., 11.5 , 17.25,  7.5 ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 27),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 50, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 28, label: chan28, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan28', array([ 57.25,  57.75,  62.75, ..., -59.5 , -38.75, -46.  ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 28),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 59, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 29, label: chan29, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan29', array([  6.25,  -8.5 , -10.5 , ...,  30.25,  40.25,  30.5 ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 29),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 40, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 30, label: chan30, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan30', array([ 84.5 ,  81.  ,  76.25, ..., -35.5 , -26.5 , -24.  ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 30),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 49, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 31, label: chan31, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan31', array([ -77.25, -104.25, -123.  , ...,  -46.25,  -33.75,  -50.  ],
#       dtype=float32), '(1.0/1000.0*s)', 'Hz', 31),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 30, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 32, label: chan32, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan32', array([ 73.5 ,  60.  ,  44.75, ..., -39.25, -11.25,   3.5 ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 32),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 83, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 33, label: chan33, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan33', array([ 39.75,  30.5 ,  23.25, ..., -33.75, -18.5 ,  -8.5 ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 33),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 84, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 34, label: chan34, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan34', array([ 60.5 ,  51.  ,  46.75, ..., 102.5 , 124.  , 130.75], dtype=float32), '(1.0/1000.0*s)', 'Hz', 34),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 73, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 35, label: chan35, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan35', array([-16.5 , -36.  , -51.75, ...,  19.  ,  35.25,  34.  ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 35),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 74, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 36, label: chan36, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan36', array([ 0.25, 19.  , 24.25, ...,  5.25,  4.5 ,  3.75], dtype=float32), '(1.0/1000.0*s)', 'Hz', 36),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 63, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 37, label: chan37, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan37', array([-22.  , -34.5 , -33.75, ..., -13.  ,  -6.75,  -9.  ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 37),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((1, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 64, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 38, label: chan38, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan38', array([81.75, 61.  , 68.75, ..., -8.5 , -2.25, -5.  ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 38),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 53, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 39, label: chan39, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan39', array([-27.25, -32.5 , -32.75, ...,   6.75,  25.  ,  36.25], dtype=float32), '(1.0/1000.0*s)', 'Hz', 39),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 54, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 40, label: chan40, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan40', array([ -5.  , -12.5 , -17.25, ..., -17.  , -14.5 , -21.  ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 40),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 43, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 41, label: chan41, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan41', array([-15.75, -20.  , -11.5 , ...,  38.  ,  34.5 ,  41.25], dtype=float32), '(1.0/1000.0*s)', 'Hz', 41),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 55, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 42, label: chan42, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan42', array([ 116.5 ,  103.75,   91.5 , ..., -109.5 , -104.25,  -97.75],
#       dtype=float32), '(1.0/1000.0*s)', 'Hz', 42),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 44, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 43, label: chan43, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan43', array([ 12.  ,  20.25,  14.5 , ..., -19.5 , -22.  , -15.25], dtype=float32), '(1.0/1000.0*s)', 'Hz', 43),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 45, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 44, label: chan44, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan44', array([72.  , 35.75, 56.5 , ..., 29.75, 45.  , 41.5 ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 44),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((1, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 1, 'uV', 1, 'Hz', 33, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 45, label: chan45, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan45', array([ 13.75,  11.25,  19.75, ..., -18.  ,  -0.75,   3.5 ], dtype=float32), '(1.0/1000.0*s)', 'Hz', 45),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((1, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 46, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 46, label: chan46, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan46', array([-114.75, -124.25, -113.75, ...,  286.5 ,  289.25,  276.25],
#       dtype=float32), '(1.0/1000.0*s)', 'Hz', 46),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_filter_hi_pass_freq', 'O'), ('an_filter_shift_correctio', 'O'), ('an_electrode_reject_HFC', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('signal_units', 'O'), ('an_filter_hi_pass_order', 'O'), ('an_filter_hi_pass_freq_units', 'O'), ('an_connector_aligned_id', 'O'), ('an_filter_lo_pass_freq', 'O'), ('sampling_rate', 'O'), ('an_filter_type', 'O'), ('description', 'O'), ('t_start', 'O'), ('an_filter_shift_correctio_units', 'O'), ('an_filter_lo_pass_order', 'O'), ('an_nsx', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('signal', 'O'), ('t_start_units', 'O'), ('an_filter_lo_pass_freq_units', 'O'), ('an_channel_id', 'O')]),
#        array((0, 0.3, 2.1, 0, '../datasets/i140703-001.ns2', 0, 'uV', 1, 'Hz', 34, 250.0, 1000.0, 'butterworth', 'AnalogSignal from channel: 47, label: chan47, nsx: 2', -2.1, 'ms', 4, 2, 'Hz', 'chan47', array([  8.75,  -4.75, -21.5 , ...,   9.5 ,  23.75,  30.25], dtype=float32), '(1.0/1000.0*s)', 'Hz', 47),
# ...
#        3.0090827e+07, 3.0094771e+07]), '(1.0/30000 * s)', 1, 94),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_connector_aligned_id', 'O'), ('an_mua', 'O'), ('an_electrode_reject_HFC', 'O'), ('an_sua', 'O'), ('an_spike_duration', 'O'), ('an_spike_amplitude', 'O'), ('an_electrode_reject_IFC', 'O'), ('waveforms', 'O'), ('t_stop', 'O'), ('an_spike_count', 'O'), ('sampling_rate', 'O'), ('description', 'O'), ('file_origin', 'O'), ('t_stop_units', 'O'), ('t_start', 'O'), ('an_noise', 'O'), ('left_sweep', 'O'), ('waveforms_units', 'O'), ('times_units', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('an_SNR', 'O'), ('t_start_units', 'O'), ('times', 'O'), ('left_sweep_units', 'O'), ('an_unit_id', 'O'), ('an_channel_id', 'O')]),
#        array((0, 18, 0, 0, 1, 566.666666667, 291.44652475, 0, array([[ 4.75,  6.5 ,  9.  , ...,  1.5 ,  2.  , -0.25],
#        [-4.  ,  3.  ,  5.5 , ..., 16.25, 12.25, 11.5 ],
#        [-1.5 , -6.25, -8.5 , ..., 26.  , 24.  , 22.5 ],
#        ...,
#        [ 4.  ,  2.  , -0.25, ..., 20.  , 15.75, 12.  ],
#        [ 6.25, 12.25, 11.  , ...,  7.5 , 10.5 , 18.25],
#        [19.  , 15.25,  8.75, ..., 15.5 ,  3.25, -5.5 ]]), 30096367.0, 3899, 30000.0, 'SpikeTrain from channel: 94, unit: 2', '../datasets/i140703-001-03.nev', '(1.0/30000 * s)', 0.0, 0, 10.0, 'uV', '(1.0/30000 * s)', 'Hz', 'Unit 94002', 2.62270381146, '(1.0/30000 * s)', array([9.6400000e+03, 2.3981000e+04, 3.2029000e+04, ..., 3.0058608e+07,
#        3.0072140e+07, 3.0086648e+07]), '(1.0/30000 * s)', 2, 94),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_connector_aligned_id', 'O'), ('an_mua', 'O'), ('an_electrode_reject_HFC', 'O'), ('an_sua', 'O'), ('an_spike_duration', 'O'), ('an_spike_amplitude', 'O'), ('an_electrode_reject_IFC', 'O'), ('waveforms', 'O'), ('t_stop', 'O'), ('an_spike_count', 'O'), ('sampling_rate', 'O'), ('description', 'O'), ('file_origin', 'O'), ('t_stop_units', 'O'), ('t_start', 'O'), ('an_noise', 'O'), ('left_sweep', 'O'), ('waveforms_units', 'O'), ('times_units', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('an_SNR', 'O'), ('t_start_units', 'O'), ('times', 'O'), ('left_sweep_units', 'O'), ('an_unit_id', 'O'), ('an_channel_id', 'O')]),
#        array((0, 20, 0, 0, 0, '../datasets/i140703-001-03.nev', 0, array([[ -2.75,  -7.  ,  -8.75, ...,  91.5 ,  84.  ,  75.  ],
#        [  6.75,   2.75,   1.75, ...,  79.25,  69.  ,  58.25],
#        [ -3.5 ,  -0.25,   0.25, ...,  34.  ,  27.75,  23.75],
#        ...,
#        [-17.5 , -15.  , -12.75, ...,   9.5 ,   2.75,  -3.  ],
#        [  0.25,  -7.  , -12.5 , ...,  38.75,  30.5 ,  22.  ],
#        [ 31.  ,  37.75,  37.5 , ...,  20.75,  18.25,  19.  ]]), 30096367.0, 30000.0, 'SpikeTrain from channel: 95, unit: unclassified', '(1.0/30000 * s)', 0.0, 1, 10.0, 'uV', '(1.0/30000 * s)', 'Hz', 'Unit 95000', '(1.0/30000 * s)', array([2.4240000e+04, 6.4466000e+04, 1.0873800e+05, ..., 3.0020342e+07,
#        3.0062621e+07, 3.0066211e+07]), '(1.0/30000 * s)', 0, 95),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_connector_aligned_id', 'O'), ('an_mua', 'O'), ('an_electrode_reject_HFC', 'O'), ('an_sua', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('waveforms', 'O'), ('t_stop', 'O'), ('sampling_rate', 'O'), ('description', 'O'), ('t_stop_units', 'O'), ('t_start', 'O'), ('an_noise', 'O'), ('left_sweep', 'O'), ('waveforms_units', 'O'), ('times_units', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('t_start_units', 'O'), ('times', 'O'), ('left_sweep_units', 'O'), ('an_unit_id', 'O'), ('an_channel_id', 'O')]),
#        array((0, 20, 0, 0, 1, 300.0, 859.677345755, 0, array([[ -2.25,   3.75,   9.25, ...,  33.  ,  24.5 ,  21.75],
#        [ 11.75,   7.  ,   5.75, ...,  28.25,  22.25,  17.75],
#        [-10.75,  -8.25,  -4.75, ...,  24.  ,  23.75,  25.5 ],
#        ...,
#        [  0.  ,  -8.  , -19.5 , ...,  20.25,  24.5 ,  29.5 ],
#        [ -4.5 ,  -4.  ,  -6.  , ...,  30.5 ,  27.  ,  22.25],
#        [ -3.  ,  -3.25,  -6.  , ...,  42.  ,  36.5 ,  28.5 ]]), 30096367.0, 10519, 30000.0, 'SpikeTrain from channel: 95, unit: 1', '../datasets/i140703-001-03.nev', '(1.0/30000 * s)', 0.0, 0, 10.0, 'uV', '(1.0/30000 * s)', 'Hz', 'Unit 95001', 9.11689931957, '(1.0/30000 * s)', array([1.9940000e+03, 5.8550000e+03, 9.4210000e+03, ..., 3.0078001e+07,
#        3.0079691e+07, 3.0092499e+07]), '(1.0/30000 * s)', 1, 95),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_connector_aligned_id', 'O'), ('an_mua', 'O'), ('an_electrode_reject_HFC', 'O'), ('an_sua', 'O'), ('an_spike_duration', 'O'), ('an_spike_amplitude', 'O'), ('an_electrode_reject_IFC', 'O'), ('waveforms', 'O'), ('t_stop', 'O'), ('an_spike_count', 'O'), ('sampling_rate', 'O'), ('description', 'O'), ('file_origin', 'O'), ('t_stop_units', 'O'), ('t_start', 'O'), ('an_noise', 'O'), ('left_sweep', 'O'), ('waveforms_units', 'O'), ('times_units', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('an_SNR', 'O'), ('t_start_units', 'O'), ('times', 'O'), ('left_sweep_units', 'O'), ('an_unit_id', 'O'), ('an_channel_id', 'O')]),
#        array((0, 20, 0, 0, 1, 433.333333333, 424.251444105, 0, array([[ 22.25,  17.  ,  10.25, ...,  23.25,  20.  ,  13.75],
#        [  8.  ,   9.75,   6.75, ...,  25.  ,  24.25,  19.25],
#        [  6.5 ,   9.  ,  10.5 , ...,   5.75,   8.75,   7.  ],
#        ...,
#        [  3.5 ,   4.25,   0.25, ...,   8.  ,   4.25,   4.25],
#        [  7.75,   1.75,  -4.  , ...,  15.75,  18.  ,  15.75],
#        [-10.75,  -7.5 ,  -0.25, ...,  22.25,  19.  ,  12.25]]), 30096367.0, 8829, 30000.0, 'SpikeTrain from channel: 95, unit: 2', '../datasets/i140703-001-03.nev', '(1.0/30000 * s)', 0.0, 0, 10.0, 'uV', '(1.0/30000 * s)', 'Hz', 'Unit 95002', 5.73941706334, '(1.0/30000 * s)', array([1.6440000e+03, 4.9590000e+03, 9.0950000e+03, ..., 3.0088127e+07,
#        3.0088805e+07, 3.0093715e+07]), '(1.0/30000 * s)', 2, 95),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_connector_aligned_id', 'O'), ('an_mua', 'O'), ('an_electrode_reject_HFC', 'O'), ('an_sua', 'O'), ('an_spike_duration', 'O'), ('an_spike_amplitude', 'O'), ('an_electrode_reject_IFC', 'O'), ('waveforms', 'O'), ('t_stop', 'O'), ('an_spike_count', 'O'), ('sampling_rate', 'O'), ('description', 'O'), ('file_origin', 'O'), ('t_stop_units', 'O'), ('t_start', 'O'), ('an_noise', 'O'), ('left_sweep', 'O'), ('waveforms_units', 'O'), ('times_units', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('an_SNR', 'O'), ('t_start_units', 'O'), ('times', 'O'), ('left_sweep_units', 'O'), ('an_unit_id', 'O'), ('an_channel_id', 'O')]),
#        array((0, 20, 0, 0, 1, 300.0, 331.828726778, 0, array([[ -0.75,   0.  ,   1.  , ..., -12.75, -15.5 , -22.75],
#        [  4.5 ,   3.75,   2.  , ...,  27.5 ,  35.25,  36.75],
#        [-12.25, -16.25, -15.  , ...,   1.  ,  -0.25,   1.  ],
#        ...,
#        [-10.  ,  -7.75,  -4.  , ...,   4.25,   2.  ,   1.5 ],
#        [  9.25,   1.75,  -5.25, ..., -32.  , -21.75, -12.  ],
#        [  4.5 ,  11.  ,  15.  , ...,   2.25,  -5.5 , -10.25]]), 30096367.0, 2207, 30000.0, 'SpikeTrain from channel: 95, unit: 3', '../datasets/i140703-001-03.nev', '(1.0/30000 * s)', 0.0, 0, 10.0, 'uV', '(1.0/30000 * s)', 'Hz', 'Unit 95003', 3.91980919193, '(1.0/30000 * s)', array([   32329.,    61508.,    61963., ..., 30071949., 30085106.,
#        30090256.]), '(1.0/30000 * s)', 3, 95),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_connector_aligned_id', 'O'), ('an_mua', 'O'), ('an_electrode_reject_HFC', 'O'), ('an_sua', 'O'), ('an_spike_duration', 'O'), ('an_spike_amplitude', 'O'), ('an_electrode_reject_IFC', 'O'), ('waveforms', 'O'), ('t_stop', 'O'), ('an_spike_count', 'O'), ('sampling_rate', 'O'), ('description', 'O'), ('file_origin', 'O'), ('t_stop_units', 'O'), ('t_start', 'O'), ('an_noise', 'O'), ('left_sweep', 'O'), ('waveforms_units', 'O'), ('times_units', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('an_SNR', 'O'), ('t_start_units', 'O'), ('times', 'O'), ('left_sweep_units', 'O'), ('an_unit_id', 'O'), ('an_channel_id', 'O')]),
#        array((0, 9, 0, 0, 0, '../datasets/i140703-001-03.nev', 0, array([[-13.  , -16.  , -19.25, ...,  41.75,  36.5 ,  24.25],
#        [ 30.5 ,  29.25,  22.  , ...,  61.25,  52.75,  44.25],
#        [ -5.5 ,  -5.  ,   0.  , ...,  23.5 ,  23.25,  22.5 ],
#        ...,
#        [ 29.5 ,  34.75,  37.5 , ...,  10.25,   6.75,  -5.25],
#        [  1.5 ,  -7.25, -14.  , ...,  11.25,  10.25,   7.25],
#        [-14.  , -10.25, -10.5 , ...,  18.5 ,  10.  ,   0.25]]), 30096367.0, 30000.0, 'SpikeTrain from channel: 96, unit: unclassified', '(1.0/30000 * s)', 0.0, 1, 10.0, 'uV', '(1.0/30000 * s)', 'Hz', 'Unit 96000', '(1.0/30000 * s)', array([   32361.,    34921.,   108771., ..., 29971708., 29978708.,
#        30004550.]), '(1.0/30000 * s)', 0, 96),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_connector_aligned_id', 'O'), ('an_mua', 'O'), ('an_electrode_reject_HFC', 'O'), ('an_sua', 'O'), ('file_origin', 'O'), ('an_electrode_reject_IFC', 'O'), ('waveforms', 'O'), ('t_stop', 'O'), ('sampling_rate', 'O'), ('description', 'O'), ('t_stop_units', 'O'), ('t_start', 'O'), ('an_noise', 'O'), ('left_sweep', 'O'), ('waveforms_units', 'O'), ('times_units', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('t_start_units', 'O'), ('times', 'O'), ('left_sweep_units', 'O'), ('an_unit_id', 'O'), ('an_channel_id', 'O')]),
#        array((0, 9, 0, 0, 1, 266.666666667, 406.115986688, 0, array([[ -2.75,  -1.25,  -2.25, ...,  18.25,   7.75,   1.  ],
#        [ -1.5 ,  -3.  ,  -6.  , ...,   6.5 ,   5.5 ,   8.  ],
#        [  4.5 ,   8.5 ,  12.75, ...,  12.75,  18.25,  13.75],
#        ...,
#        [ -4.25,  -9.5 , -14.25, ...,  15.25,  11.  ,  11.25],
#        [  5.5 ,   9.5 ,  15.  , ...,  -8.75, -19.75, -26.5 ],
#        [ -6.  ,  -6.5 ,  -9.  , ...,  10.5 ,   4.5 ,  -3.25]]), 30096367.0, 8113, 30000.0, 'SpikeTrain from channel: 96, unit: 1', '../datasets/i140703-001-03.nev', '(1.0/30000 * s)', 0.0, 0, 10.0, 'uV', '(1.0/30000 * s)', 'Hz', 'Unit 96001', 4.48632293026, '(1.0/30000 * s)', array([3.2350000e+03, 7.8110000e+03, 1.1061000e+04, ..., 3.0065432e+07,
#        3.0070061e+07, 3.0084826e+07]), '(1.0/30000 * s)', 1, 96),
#       dtype=[('an_electrode_reject_LFC', 'O'), ('an_connector_aligned_id', 'O'), ('an_mua', 'O'), ('an_electrode_reject_HFC', 'O'), ('an_sua', 'O'), ('an_spike_duration', 'O'), ('an_spike_amplitude', 'O'), ('an_electrode_reject_IFC', 'O'), ('waveforms', 'O'), ('t_stop', 'O'), ('an_spike_count', 'O'), ('sampling_rate', 'O'), ('description', 'O'), ('file_origin', 'O'), ('t_stop_units', 'O'), ('t_start', 'O'), ('an_noise', 'O'), ('left_sweep', 'O'), ('waveforms_units', 'O'), ('times_units', 'O'), ('sampling_rate_units', 'O'), ('name', 'O'), ('an_SNR', 'O'), ('t_start_units', 'O'), ('times', 'O'), ('left_sweep_units', 'O'), ('an_unit_id', 'O'), ('an_channel_id', 'O')])],
#       dtype=object), 'Segment 0', '../datasets/i140703-001', array([], dtype=float64), 1, array([array(('(1.0/30000 * s)', 'Trial events of the digital input port', array([   39424,    39424,    39424, ..., 29889563, 29889563,       -1]), array(['65296', '65360', '65370', ..., '65514', '65312', '65296'],
#       dtype='<U5'), array(['TS-ON      ', 'WS-ON      ', 'CUE-ON     ', ..., 'RW-ON      ',
#        'STOP       ', 'NONE       '], dtype='<U11'), array([0, 0, 0, ..., 0, 0, 0], dtype=uint8), array([255, 255, 255, ..., 255, 255,   0]), array([   39424.,    51491.,    63532., ..., 29992800., 30001060.,
#        30088013.]), array(['SGHF', 'SGHF', 'SGHF', ..., 'SGLF', 'SGLF', 'NONE'], dtype='<U4'), array([  1,   1,   1, ..., 161, 161,  -1]), array([0, 0, 0, ..., 0, 0, 0], dtype=uint8), array([1, 1, 1, ..., 0, 0, 0], dtype=uint8), 'DigitalTrialEvents'),
#       dtype=[('times_units', 'O'), ('description', 'O'), ('an_trial_timestamp_id', 'O'), ('labels', 'O'), ('an_trial_event_labels', 'O'), ('an_trial_reject_LFC', 'O'), ('an_performance_in_trial', 'O'), ('times', 'O'), ('an_belongs_to_trialtype', 'O'), ('an_trial_id', 'O'), ('an_trial_reject_HFC', 'O'), ('an_trial_reject_IFC', 'O'), ('name', 'O')]),
#        array(('ms', 'Events extracted from analog signals', array([   39424,    39424,    39424, ..., 29889563, 29889563, 29889563]), array(['OT         ', 'OR         ', 'FSRplat-ON ', ..., 'OBB        ',
#        'HEplat-ON  ', 'HEplat-OFF '], dtype='<U11'), array(['OT         ', 'OR         ', 'FSRplat-ON ', ..., 'OBB        ',
#        'HEplat-ON  ', 'HEplat-OFF '], dtype='<U11'), array([0, 0, 0, ..., 0, 0, 0], dtype=uint8), array([255, 255, 255, ..., 255, 255, 255]), array([  3911.,   5083.,   3977., ..., 994315., 993131., 993635.]), array(['SGHF', 'SGHF', 'SGHF', ..., 'SGLF', 'SGLF', 'SGLF'], dtype='<U4'), array([  1,   1,   1, ..., 161, 161, 161]), array([0, 0, 0, ..., 0, 0, 0], dtype=uint8), array([1, 1, 1, ..., 0, 0, 0], dtype=uint8), 'AnalogTrialEvents'),
#       dtype=[('times_units', 'O'), ('description', 'O'), ('an_trial_timestamp_id', 'O'), ('labels', 'O'), ('an_trial_event_labels', 'O'), ('an_trial_reject_LFC', 'O'), ('an_performance_in_trial', 'O'), ('times', 'O'), ('an_belongs_to_trialtype', 'O'), ('an_trial_id', 'O'), ('an_trial_reject_HFC', 'O'), ('an_trial_reject_IFC', 'O'), ('name', 'O')]),
#        array(('(1.0/30000 * s)', 'All trial events (digital and analog)', array([28779900,  6104193,  6104193, ..., 29889563, 29889563,       -1]), array(['DO         ', 'OBB        ', 'DO         ', ..., 'RW-ON      ',
#        'STOP       ', 'NONE       '], dtype='<U11'), array(['DO         ', 'OBB        ', 'DO         ', ..., 'RW-ON      ',
#        'STOP       ', 'NONE       '], dtype='<U11'), array([0, 0, 0, ..., 0, 0, 0], dtype=uint8), array([167, 159, 159, ..., 255, 255,   0]), array([-1.0000000e+00, -1.0000000e+00, -1.0000000e+00, ...,
#         2.9992800e+07,  3.0001060e+07,  3.0088013e+07]), array(['PG  ', 'SGHF', 'SGHF', ..., 'SGLF', 'SGLF', 'NONE'], dtype='<U4'), array([155,  34,  34, ..., 161, 161,  -1]), array([0, 0, 0, ..., 0, 0, 0], dtype=uint8), array([0, 0, 0, ..., 0, 0, 0], dtype=uint8), 'TrialEvents'),
#       dtype=[('times_units', 'O'), ('description', 'O'), ('an_trial_timestamp_id', 'O'), ('labels', 'O'), ('an_trial_event_labels', 'O'), ('an_trial_reject_LFC', 'O'), ('an_performance_in_trial', 'O'), ('times', 'O'), ('an_belongs_to_trialtype', 'O'), ('an_trial_id', 'O'), ('an_trial_reject_HFC', 'O'), ('an_trial_reject_IFC', 'O'), ('name', 'O')])],
#       dtype=object), '2014-07-03 10:40:59.000288', 'Segment containing data from t_min to t_max.'),
#       dtype=[('index', 'O'), ('analogsignals', 'O'), ('spiketrains', 'O'), ('name', 'O'), ('file_origin', 'O'), ('epochs', 'O'), ('an_condition', 'O'), ('events', 'O'), ('rec_datetime', 'O'), ('description', 'O')]), 0, 400.0, '8596-001139', 'left', 'um', 1, 'Block of reach-to-grasp project data from Blackrock file set.', 1, 1, 100, 'Reachgrasp Recording Data Block', 1, array(['ccf ', 'odml', 'nev ', 'ns2 ', 'ns6 '], dtype='<U4'), 0, 'monkey_N', 'Inst. de Neurosciences de la Timone (INT), UMR 7289, CNRS - Aix Marseille Univ., Marseille, France', 10, 'TwoCues', '2014-07-03 10:40:59.000288'),
#       dtype=[('an_nb_segments', 'O'), ('an_project_subtype', 'O'), ('file_origin', 'O'), ('an_arraygrid_col_num', 'O'), ('an_avail_electrode_ids', 'O'), ('an_project_name', 'O'), ('an_project_type', 'O'), ('an_subject_birthday', 'O'), ('an_connector_type', 'O'), ('an_avail_nsx', 'O'), ('an_subject_gender', 'O'), ('segments', 'O'), ('an_rec_pauses', 'O'), ('an_electrodes_pitch', 'O'), ('an_array_serialnum', 'O'), ('an_subject_activehand', 'O'), ('an_electrodes_pitch_units', 'O'), ('an_conditions', 'O'), ('description', 'O'), ('an_avail_nev', 'O'), ('an_arraygrids_tot_num', 'O'), ('an_electrodes_tot_num', 'O'), ('name', 'O'), ('an_avail_ccf', 'O'), ('an_avail_file_set', 'O'), ('an_avail_sif', 'O'), ('an_subject_name', 'O'), ('an_setup_location', 'O'), ('an_arraygrid_row_num', 'O'), ('an_taskdesigns', 'O'), ('rec_datetime', 'O')])

# %% [markdown]
# ### Data preprocessing
# Spectrogram is computed in two ways: whole-recording and trial-epoched.
# - For whole-recording (all), spectrogram is computed as normal, i.e. non-overlaping sliding window.
# - For trial-epoched, 1-second of data immediately preceding (pre) and following (move) the onset of movement is grabbed, and a PSD is computed (effectively Hamming windowed FFT). Trial type information (which finger) and whether there was trial overlap during both pre and move period is stored.

# %%
def lfpca_kjm(data_path, subj, fs, analysis_param):
    # load data & trial info
    stim_info = io.loadmat(data_path+'data/'+subj+'/'+subj+'_stim.mat', squeeze_me=True)
    data = io.loadmat(data_path+'data/'+subj+'/'+subj+'_fingerflex.mat', squeeze_me=True)
    ecog = data['data'].T
    
    trial_inds = np.where(np.diff((stim_info['stim']>0).astype(int))==1)[0]+1
    trial_type = stim_info['stim'][trial_inds]

    win_len = int(fs)
    num_chan = ecog.shape[0]
    num_trials = len(trial_inds)
    max_freq = analysis_param['max_freq']

    # pre-initialize arrays
    psd_precomp = np.zeros((num_chan, max_freq, num_trials, 2))
    pre_overlap = np.zeros(num_trials)
    post_overlap = np.zeros(num_trials)

    # precompute trial PSDs
    for tr, ind in enumerate(trial_inds):
        # pre-movement
        f_axis, p_ = ndsp.spectral.psd(ecog[:,ind-win_len:ind], Fs=fs, nperseg=win_len)        
        psd_precomp[:,:,tr,0] = p_[:,:max_freq]
        pre_overlap[tr] = 1-np.all(stim_info['stim'][ind-win_len:ind]<1)
        # movement
        f_axis, p_ = ndsp.spectral.psd(ecog[:,ind:ind+win_len], Fs=fs, nperseg=win_len)
        psd_precomp[:,:,tr,1] = p_[:,:max_freq]
        post_overlap[tr] = 1-np.all(stim_info['stim'][ind:ind+win_len]==stim_info['stim'][ind])

    print('%i trials; %i pre-movement overlap; %i post-movement overlap'%(num_trials,pre_overlap.sum(), post_overlap.sum()))

    lfpca_all = []
    for i in range(2):
        mov_lfpca = lfpca.LFPCA(analysis_param)
        mov_lfpca.populate_fourier_data(psd_precomp[:,:,:,i], fs, f_axis)
        mov_lfpca.compute_psd()
        mov_lfpca.compute_scv()
        lfpca_all.append(mov_lfpca)
    
    # return the pre- and during-movement lfpca data, and trial info
    return lfpca_all, np.array([trial_type, pre_overlap, post_overlap])

def plot_contrast(lfpca_all, elec_def, elec_loc, labels, savepath):
    for chan in range(lfpca_all[0].numchan):
        for ind, lf in enumerate(lfpca_all):
            # PSD
            plt.subplot(1,3,1)
            plt.loglog(lf.f_axis,lf.psd[chan,:], alpha=0.5)
            plt.xlim([1,200])
            plt.ylabel('PSD')
            try:
                plt.title(elec_def[elec_loc[chan].astype(str)])
            except:
                plt.title('others')
            # SCV
            plt.subplot(1,3,2)
            plt.loglog(lf.f_axis,lf.scv[chan,:], alpha=0.5)
            plt.ylabel('SCV')
            plt.xlim([1,200])
            plt.ylim([0.5, 5])
            # p-val
            plt.subplot(1,3,3)
            plt.loglog(lf.f_axis,lf.ks_pvals[chan,:], alpha=0.5)
            plt.ylabel('KS p-val')
            plt.xlim([1,200])
            plt.ylim([1e-7, 1])
            
        plt.legend(labels)
        # draw unity line for SCV and p<0.01 for p-val
        plt.subplot(1,3,2)
        plt.loglog(lf.f_axis,np.ones_like(lf.f_axis), 'k--', alpha=0.5)
        plt.subplot(1,3,3)
        plt.loglog(lf.f_axis,0.01*np.ones_like(lf.f_axis), 'k--', alpha=0.5)
        plt.tight_layout()
        # save out
        plt.savefig(savepath + '_' + str(chan) + '.png')
        plt.clf()

# %%
# define data folder
data_path = '/Users/rdgao/Documents/data/ECoG_KJM/digit/'
saveout_path = '../results/kjm_digits/'
save_files = ['pre','move','whole']
subjs = ['bp', 'cc', 'ht', 'jc', 'jp', 'mv', 'wc', 'wm', 'zt']

# electrode location
elec_def = {
    '1': 'dorsal M1',
    '3': 'dorsal S1',
    '4': 'ventral S1+M1',
    '6': 'frontal (non-R)',
    '7': 'parietal (non-R)',
    '8': 'temporal',
    '9': 'occipital'
}

# %%
fs = 1000.
# lfpca params
analysis_param = {'nperseg': 1000,
                 'noverlap': 0,
                 'spg_outlierpct': 2.,
                 'max_freq':200}

for subj in subjs:
    print(subj)
    # get the trial-separated LFPCA
    lfpca_all, trial_info = lfpca_kjm(data_path,subj,fs,analysis_param)
    
    # get LFPCA for whole recording
    data = io.loadmat(data_path+'data/'+subj+'/'+subj+'_fingerflex.mat', squeeze_me=True)    
    lfpca_all.append(lfpca.LFPCA(analysis_param))
    lfpca_all[-1].populate_ts_data(data['data'].T, fs)
    lfpca_all[-1].compute_all_spectral()
    
    # make dir
    subj_path = saveout_path+subj+'/'
    if not os.path.isdir(subj_path):
        os.mkdir(subj_path)
    
    print('Computing exponential KS test...')
    for ind, lf in enumerate(lfpca_all):
        # compute fit
        lf.compute_KS_expfit()
        # save out LFPCA         
        lf.save_spec_vars(subj_path+save_files[ind]+'.npz', save_spg=True)
    
    # save trial info and plot contrast
    np.savez(subj_path+'trial_info.npz', trial_info=trial_info, elec_regions=data['elec_regions'])
    
    figure_savepath = saveout_path+'scv_figs/'+subj    
    plt.figure(figsize=(15,5))
    plot_contrast(lfpca_all, elec_def, data['elec_regions'], save_files, figure_savepath)
# Out:
# bp
# 148 trials; 8 pre-movement overlap; 1 post-movement overlap
# Computing exponential KS test...
# /Users/rdgao/anaconda3/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py:106: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
# cc
# 151 trials; 36 pre-movement overlap; 2 post-movement overlap
# Computing exponential KS test...
# ht
# 151 trials; 24 pre-movement overlap; 1 post-movement overlap
# Computing exponential KS test...
# jc
# 132 trials; 4 pre-movement overlap; 2 post-movement overlap
# Computing exponential KS test...
# jp
# 118 trials; 92 pre-movement overlap; 9 post-movement overlap
# Computing exponential KS test...
# mv
# 31 trials; 21 pre-movement overlap; 1 post-movement overlap
# Computing exponential KS test...
# wc
# 154 trials; 58 pre-movement overlap; 4 post-movement overlap
# Computing exponential KS test...
# wm
# 91 trials; 22 pre-movement overlap; 15 post-movement overlap
# Computing exponential KS test...
# zt
# 149 trials; 62 pre-movement overlap; 2 post-movement overlap
# Computing exponential KS test...

# %% [markdown]
# ### old code below (pre-lfpca)

# %% [markdown]
# ### spectral PCA

# %%
from sklearn.decomposition import PCA

# %%
num_freq = 100
chan = 0
f_axis, t_axis, spg = sp.signal.spectrogram(ecog[:,chan], fs=fs, nperseg=int(fs), noverlap=0)
pca = PCA(n_components=3)
pca.fit(np.log10(np.abs(spg**2).T))

plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.semilogx(f_axis[1:200],pca.components_[:,1:200].T, alpha=0.5)
plt.plot([1,200], [0,0], 'k--')
plt.legend(('PC1', 'PC2', 'PC3'))

plt.subplot(1,2,2)
plt.imshow(sp.corrcoef(np.log10(np.abs(spg**2)))[:num_freq,:num_freq]*(np.ones((num_freq, num_freq))-np.eye(num_freq)))
#plt.colorbar()

# %% [markdown]
# ### save out all PSD and SCV plots

# %%
data_path = '/Users/rgao/Documents/Data/ECoG_KJM/digit/'
subjs = ['bp', 'cc', 'ht', 'jc', 'jp', 'mv', 'wc', 'wm', 'zt']
elec_regios = {
    '1': 'dorsal M1',
    '3': 'dorsal S1',
    '4': 'ventral S1+M1',
    '6': 'frontal (non-R)',
    '7': 'parietal (non-R)',
    '8': 'temporal',
    '9': 'occipital'
}

plt.figure(figsize=(8,4))
for subj in subjs: 
    print(subj)
    data = io.loadmat(data_path+'data/'+subj+'/'+subj+'_fingerflex.mat', squeeze_me=True)
    ecog = data['data']
    fs = 1000.
    num_samp, num_chan = np.shape(ecog)
    # compute PSD
    freqs, psd_mean = ndsp.spectral.psd(ecog.T,Fs=fs, method='mean')
    _, psd_med = ndsp.spectral.psd(ecog.T,Fs=fs, method='median')
    scv = np.zeros((int(fs/2+1), num_chan))
    for chan in range(num_chan):
        freqs, scv[:,chan] = ndsp.spectral.scv(ecog[:,chan], Fs=fs)
        try:
            ele_name = elec_regios[str(data['elec_regions'][chan])]
        except:
            ele_name = 'others'

        # make & save plots
        plt.subplot(1,2,1)
        plt.loglog(freqs[:200], psd_mean[chan,:200].T, lw=1, alpha=0.5)
        plt.loglog(freqs[:200], psd_med[chan,:200].T, lw=1, alpha=0.5)
        plt.legend(('mean welch', 'med welch'))
        plt.subplot(1,2,2)
        plt.loglog(freqs[:300], scv[:300, chan], 'k', lw=1, alpha=0.5)
        plt.legend([ele_name])
        plt.plot([1,200], [1,1], 'k--')
        plt.plot([100,100], [0.5,4], 'k--');
        plt.xlim([1, 300])
        plt.ylim([0.5, 4])
        plt.tight_layout()
        # save out
        plt.savefig(data_path+'/scv_figs/'+subj+'_' + str(chan) + '.png')
        plt.clf()
# Out:
# bp
# cc
# ht
# jc
# jp
# mv
# wc
# wm
# zt
